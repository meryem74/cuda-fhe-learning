# %%
# !apt-get update -qq
# !apt-get install -y -qq build-essential git wget curl ca-certificates unzip pkg-config libgmp-dev libssl-dev
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Preconfiguring packages ...
# (Reading database ... 118243 files and directories currently installed.)
# Removing r-base-dev (4.6.0-4.2204.0) ...
# dpkg: pkgconf: dependency problems, but removing anyway as you requested:
#  libsndfile1-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libmkl-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libglib2.0-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libfontconfig-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
# ...

# %%
# !wget -q https://go.dev/dl/go1.22.3.linux-amd64.tar.gz -O /tmp/go.tar.gz
# !tar -C /usr/local -xzf /tmp/go.tar.gz
import os
os.environ['PATH'] = '/usr/local/go/bin:' + os.environ['PATH']
# !go version
# Out:
# go version go1.22.3 linux/amd64

# %%
# !git clone https://github.com/baahl-nyu/orion.git
# %cd orion
# !pip install -e .
# Out:
# Cloning into 'orion'...
# remote: Enumerating objects: 1812, done.
# remote: Counting objects: 100% (438/438), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 1812 (delta 350), reused 321 (delta 298), pack-reused 1374 (from 1)
# Receiving objects: 100% (1812/1812), 2.18 MiB | 38.45 MiB/s, done.
# Resolving deltas: 100% (876/876), done.
# /content/orion
# Obtaining file:///content/orion
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 26.8 MB/s eta 0:00:00
# ...
#   Building editable for orion-fhe (pyproject.toml) ... done
# ...

# %%
# !python examples/run_lola.py
# Out:
# 100% 9.91M/9.91M [00:00<00:00, 128MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 16.5MB/s]
# 100% 1.65M/1.65M [00:00<00:00, 93.2MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 9.73MB/s]
#
# {1} Finding per-layer input/output ranges and shapes...
# Processing input data: 100% 469/469 [00:11<00:00, 40.78batch/s]
#
# {2} Fitting polynomials... done! [0.000 secs.]
#
# {3} Generating matrix diagonals...
#
# Packing conv1:
# ├── embed method: hybrid
# ├── original matrix shape: (1568, 784)
# ├── # blocks (rows, cols) = (1, 1)
# ├── resized matrix shape: (2048, 8192)
# ├── # output rotations: 2
# ├── time to pack (s): 0.22
# ├── # diagonals = 13
#
# Packing fc1:
# ├── embed method: hybrid
# ├── original matrix shape: (100, 1568)
# ├── # blocks (rows, cols) = (1, 1)
# ├── resized matrix shape: (128, 8192)
# ├── # output rotations: 6
# ├── time to pack (s): 0.03
# ├── # diagonals = 128
#
# Packing fc2:
# ├── embed method: hybrid
# ├── original matrix shape: (10, 100)
# ├── # blocks (rows, cols) = (1, 1)
# ...
